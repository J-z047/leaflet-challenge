# %%
import requests
import json

# %%
def fetch_earthquake_data(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"Failed to fetch data. Status code: {response.status_code}")

# %%
def process_earthquake_data(geojson_data):
    features = geojson_data["features"]
    for feature in features:
        properties = feature["properties"]
        mag = properties["mag"]
        place = properties["place"]
        time = properties["time"]
        latitude, longitude, depth = feature["geometry"]["coordinates"]
        
        print(f"Magnitude: {mag}, Place: {place}, Time: {time}, Latitude: {latitude}, Longitude: {longitude}, Depth: {depth}")

# %%
if __name__ == "__main__":
    url = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.geojson"
    try:
        geojson_data = fetch_earthquake_data(url)
        process_earthquake_data(geojson_data)
    except Exception as e:
        print(f"Error: {e}")
# Out:
# Magnitude: 1.5, Place: 30 km ESE of Denali National Park, Alaska, Time: 1691343306861, Latitude: -151.1229, Longitude: 63.4806, Depth: 2.7
# Magnitude: 1.7, Place: 42 km WNW of Tyonek, Alaska, Time: 1691342358664, Latitude: -151.89, Longitude: 61.1909, Depth: 88.6
# Magnitude: 1.35, Place: 0 km N of Caltech, Pasadena, CA, Time: 1691342210730, Latitude: -118.1261667, Longitude: 34.1423333, Depth: 3.53
# Magnitude: 1.4, Place: 81 km NW of Karluk, Alaska, Time: 1691342167194, Latitude: -155.2501, Longitude: 58.1709, Depth: 0
# Magnitude: 1.97, Place: 20 km WNW of Biggs, CA, Time: 1691341149620, Latitude: -121.9343338, Longitude: 39.4744987, Depth: 4.48
# Magnitude: 2.46, Place: 25 km W of Petrolia, CA, Time: 1691340361870, Latitude: -124.5818329, Longitude: 40.2956657, Depth: 18.61
# Magnitude: 1.19, Place: 2 km NNW of Fontana, CA, Time: 1691339296950, Latitude: -117.4686667, Longitude: 34.1175, Depth: 6.93
# ...
